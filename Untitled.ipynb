# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# %tensorflow_version 1.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
import seaborn as sns    
plt.figure(figsize=(19,19))
sns.heatmap(data = df.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Reds')

# %%
df.shape
# Out:
# (2550, 19)

# %%
import pandas as pd
df = pd.read_csv('ted.csv')
df = df.iloc[1:]

# %%
import matplotlib.pyplot as plt
plt.figure()
df2 = df[0:10]
#plt.plot(df['video_num'], df['Ingenious'])
plt.scatter(df['Inspiring'], df['comments'])
#plt.xlim(0,300)
#plt.ylim(0,500)
x = np.linspace(0,9000, 2)
#plt.plot(x, reg(x), c = 'r')

# %%
x_train
# Out:
# 1       203
# 2       142
# 3        85
# 4        61
# 5       335
#        ...
# 2545      0
# 2546      0
# 2547      0
# 2548      1
# 2549      0
# Name: Inspiring, Length: 2549, dtype: int64

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# %%
IQR
# Out:
# video_num         1274.0
# duration           469.0
# comments           158.0
# Funny              352.0
# Beautiful          328.0
# Ingenious          277.0
# Courageous         231.0
# Longwinded         185.0
# Confusing          133.0
# Informative        124.0
# Fascinating         82.0
# Unconvincing        67.0
# Persuasive          48.0
# Jaw-dropping        41.0
# OK                  30.0
# Obnoxious           22.0
# Inspiring           15.0
# views           942410.0
# dtype: float64

# %%
IQRx = df['Inspiring'].quantile(0.75)# - df['Inspiring'].quantile(0.25)
IQRy = df['comments'].quantile(0.75) - df['Inspiring'].quantile(0.25)
plt.scatter(IQRx, IQRy)

# %%
IQRx
# Out:
# 18.0

# %%
df['Inspiring'].quantile(0.75)
# Out:
# 18.0

# %%
import seaborn as sns
sns.pairplot(df)

# %%
import numpy as np

x_train = np.asarray(df['views'])#np.array([1., 2., 3., 4., 5., 6.])
y_train = np.asarray(df['comments'])#np.array([9., 16., 23., 30., 37., 44.])

W = 0.0
b = 0.0

n_data = len(x_train)

epochs = 5000
learning_rate = 0.01

for i in range(epochs):
    hypothesis = x_train * W + b
    cost = np.sum((hypothesis - y_train) ** 2) / n_data
    gradient_w = np.sum((W * x_train - y_train + b) * 2 * x_train) / n_data
    gradient_b = np.sum((W * x_train - y_train + b) * 2) / n_data

    W -= learning_rate * gradient_w
    b -= learning_rate * gradient_b

    if i % 100 == 0:
        print('Epoch ({:10d}/{:10d}) cost: {:10f}, W: {:10f}, b:{:10f}'.format(i, epochs, cost, W, b))

print('W: {:10f}'.format(W))
print('b: {:10f}'.format(b))
print('result : ')
print(x_train * W + b)
# Out:
# Epoch (         0/      5000) cost: 108279.890545, W: 12312062.669431, b:  3.797026
# Epoch (       100/      5000) cost:        nan, W:        nan, b:       nan
# Epoch (       200/      5000) cost:        nan, W:        nan, b:       nan
# Epoch (       300/      5000) cost:        nan, W:        nan, b:       nan
# Epoch (       400/      5000) cost:        nan, W:        nan, b:       nan
# Epoch (       500/      5000) cost:        nan, W:        nan, b:       nan
# Epoch (       600/      5000) cost:        nan, W:        nan, b:       nan
# Epoch (       700/      5000) cost:        nan, W:        nan, b:       nan
# Epoch (       800/      5000) cost:        nan, W:        nan, b:       nan
# Epoch (       900/      5000) cost:        nan, W:        nan, b:       nan
# Epoch (      1000/      5000) cost:        nan, W:        nan, b:       nan
# Epoch (      1100/      5000) cost:        nan, W:        nan, b:       nan
# ...

# %%
plt.figure()
plt.scatter(x_train,y_train)
def reg(x):
    return 2 + 3* x
x = [0,5000]
plt.plot([0,50000000], [0,5], c='r')

# %%
plt.plot([0,5])

# %%
a
# Out:
# 0.7725427513944472

# %%
b
# Out:
# 94.18548234987341

# %%
x = df['Courageous']
y = df['views']

a = np.cov(x,y)[0,1]/np.var(x)
b = y.mean() - x.mean()*a

# %%
def reg(x):
    return a*x + b

# %%
df2
# Out:
#    video_num  duration  comments  Funny  Beautiful  Ingenious  Courageous  \
# 0          1      1164      4553  19645       4573       6073        3253
# 1          2       977       265    544        139         62          58
# 2          3      1286       124    964         45        183          60
# 3          4      1116       200    760        291         32          59
# 4          5      1190       593   3202       1390        942         318
# 5          6      1305       672   1102        721        377         301
# 6          7       992       919    477       2484        320         225
# 7          8      1198        46    195         98         26          34
# 8          9      1485       852    562         70        283          60
# 9         10      1262       900    838        767        476         116
#
#    Longwinded  Confusing  Informative  Fascinating  Unconvincing  Persuasive  \
# ...

# %%
def func(x):
    return x**2
import numpy as np
x = np.linspace(-10, 10, 10)
y = [func(x[i]) for i in range(len(x))]

plt.scatter(x, y, c='red')

#y = np.random.permutation(y)
plt.plot(x, y)
plt.plot([-10,10],[-10,10])

# %%
# Out:
# array([ 30.86419753,   1.2345679 ,  60.49382716,  60.49382716,
#         11.11111111,  30.86419753,   1.2345679 ,  11.11111111,
#        100.        , 100.        ])

# %%
y
# Out:
# [100.0,
#  60.49382716049382,
#  30.864197530864196,
#  11.111111111111109,
#  1.234567901234567,
#  1.234567901234567,
#  11.111111111111114,
#  30.864197530864214,
#  60.49382716049384,
#  100.0]

# %%
x= [1,3,2,4]
y = [1,3,4,2]
plt.plot(x,y)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
X = [1,2,3]
Y = [1,2,3]

W =tf.placeholder(tf.float32)
# Out hypothesis for linear molde X * W
hypothesis = X * W

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))
#Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())
#Variables for plotting cost function
W_val = []
cost_val = []
for i in range(-30,50):
    feed_W = i * 0.1
    curr_cost, curr_W = sess.run([cost, W], feed_dict={W: feed_W})
    W_val.append(curr_W)
    cost_val.append(curr_cost)
    
# Show the cost function
plt.plot(W_val, cost_val)
plt.show()

# %%
tf.Tensor(3, shape=(), d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e1cccdc5b03b> in <module>
# ----> 1 tf.Tensor(3, shape=(1,1))
#
# TypeError: __init__() got an unexpected keyword argument 'shape'
