# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_csv('mod_close.csv', encoding='euc-kr')
ticker = pd.read_csv('ticker.csv', encoding='euc-kr')

nrow, ncol = raw_data.shape
nrow, ncol
# Out:
# (151, 1131)

# %%
#check data
raw_data
#ticker
# Out:
#            date  A005930  A000660   A051910  A005380   A068270  A005490  \
# 0    2000-01-31     4450   446878       NaN    12311       NaN    80470
# 1    2000-02-29     4051   376027       NaN    10100       NaN    67091
# 2    2000-03-31     4670   413902       NaN     9453       NaN    61710
# 3    2000-05-31     4872   303634       NaN     7526       NaN    52109
# 4    2000-06-30     5452   387095       NaN    10207       NaN    57146
# ..          ...      ...      ...       ...      ...       ...      ...
# 146  2018-10-31    43064    67628  322572.0   113160  254384.0   261854
# 147  2018-11-30    43059    69049  334909.0    98940  223587.0   249852
# 148  2019-01-31    41942    66555  360875.0   126100  209175.0   261225
# 149  2019-02-28    46265    74925  380725.0   124500  210900.0   269875
# 150  2019-03-27    44677    70010  371625.0   122750  202875.0   256525
#
#        A051900   A207940   A028260  ...  A121910  A122290  A122750  A134000  \
# ...

# %%
raw_data[ticker["종목코드"].iloc[0]]
# Out:
# 0       4450
# 1       4051
# 2       4670
# 3       4872
# 4       5452
#        ...
# 146    43064
# 147    43059
# 148    41942
# 149    46265
# 150    44677
# Name: A005930, Length: 151, dtype: int64

# %%
# 빈 데이터프레임 생성
tkrs = np.asarray(ticker["종목코드"])
ret = pd.DataFrame(np.nan,index=np.arange(raw_data.shape[0]), columns=tkrs)
#df = pd.DataFrame(np.nan, index=[0,1,2,3], columns=['A'])
ret
# Out:
#      A005930  A000660  A051910  A005380  A068270  A005490  A051900  A207940  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 146      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 147      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 148      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 149      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 150      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# ...

# %%
raw_data[ticker["종목코드"].iloc[1]].iloc[1]
# Out:
# 376027

# %%
for i in range(ncol): # # of tickers
    for j in range(nrow):
        if j == 0:
            continue
        prev = raw_data[ticker["종목코드"].iloc[i]].iloc[j-1]
        today = raw_data[ticker["종목코드"].iloc[i]].iloc[j]
        if np.isnan(prev) or np.isnan(today):
            continue
        ret[ticker["종목코드"].iloc[i]].iloc[j]= (raw_data[ticker["종목코드"].iloc[i]].iloc[j] - raw_data[ticker["종목코드"].iloc[i]].iloc[j-1]) / raw_data[ticker["종목코드"].iloc[i]].iloc[j-1]# = (raw_data[ticker["종목코드"].iloc[i]].iloc[i] - raw_data[ticker["종목코드"].iloc[i]].iloc[j-1]) / raw_data[ticker["종목코드"].iloc[i]].iloc[j-1]

# %%
ret
# Out:
#       A005930   A000660   A051910   A005380   A068270   A005490   A051900  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1   -0.089663 -0.158547       NaN -0.179595       NaN -0.166261       NaN
# 2    0.152802  0.100724       NaN -0.064059       NaN -0.080204       NaN
# 3    0.043255 -0.266411       NaN -0.203851       NaN -0.155583       NaN
# 4    0.119048  0.274874       NaN  0.356232       NaN  0.096663       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 146 -0.046835 -0.126975 -0.114725 -0.072543 -0.041016 -0.171529 -0.089828
# 147 -0.000116  0.021012  0.038246 -0.125663 -0.121065 -0.045835  0.027377
# 148 -0.025941 -0.036119  0.077532  0.274510 -0.064458  0.045519  0.008689
# 149  0.103071  0.125761  0.055005 -0.012688  0.008247  0.033113  0.088102
# 150 -0.034324 -0.065599 -0.023902 -0.014056 -0.038051 -0.049467  0.065634
#
#       A207940   A028260   A017670  ...  A121910  A122290  A122750  A134000  \
# ...

# %%
std_12m = [] #각 종목별 최근 12개월 표준편차
for i in range(0, ncol-1):
    std_12m.append(ret.iloc[-12:].std(axis=0) * np.sqrt(12))
std_12m
# Out:
# [A005930    0.201000
#  A000660    0.275088
#  A051910    0.245304
#  A005380    0.363513
#  A068270    0.643698
#               ...
#  A139200         NaN
#  A149130         NaN
#  A192520         NaN
#  A192530    0.207586
#  A307950         NaN
#  Length: 1130, dtype: float64, A005930    0.201000
#  A000660    0.275088
#  A051910    0.245304
#  A005380    0.363513
#  A068270    0.643698
#               ...
#  A139200         NaN
#  A149130         NaN
#  A192520         NaN
#  A192530    0.207586
#  A307950         NaN
#  Length: 1130, dtype: float64, A005930    0.201000
#  A000660    0.275088
#  A051910    0.245304
#  A005380    0.363513
#  A068270    0.643698
#               ...
#  A139200         NaN
#  A149130         NaN
#  A192520         NaN
#  A192530    0.207586
#  A307950         NaN
#  Length: 1130, dtype: float64, A005930    0.201000
#  A000660    0.275088
#  A051910    0.245304
#  A005380    0.363513
#  A068270    0.643698
#               ...
#  A139200         NaN
# ...

# %%
a = std_12m[0]

# %%
a.loc['A005930']
# Out:
# 0.20100045473985656

# %%
ret.iloc[-12:].std(axis=0).iloc[1130] * np.sqrt(12)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-92-bd292dbf5637> in <module>
# ----> 1 ret.iloc[-12:].std(axis=0).iloc[1130] * np.sqrt(12)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2155
#    2156             # validate the location
# -> 2157             self._validate_integer(key, axis)
#    2158
#    2159             return self._get_loc(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
# ...

# %%
np.sqrt(12)
# Out:
# 3.4641016151377544

# %%
aa = std_12m[0:]
plt.figure()
plt.hist(std_12m, 500)
plt.show()
aa
# Out:
# [0.20100045473985656,
#  0.27508839811917585,
#  0.2453041791999309,
#  0.3635125782165449,
#  0.6436979475917485,
#  0.3322515755948343,
#  0.2868191637789072,
#  0.4607883955968082,
#  0.21132252632506496,
#  0.2050870468326107,
#  0.31538692918887934,
#  0.19394000609238896,
#  0.29625575019512845,
#  0.320116946888429,
#  0.13693102002716562,
#  0.39050910362024,
#  0.155037512956773,
#  0.25940954730014676,
#  0.17145856733355705,
#  0.1394185051017236,
#  0.19330469111071336,
#  0.3060926628375489,
#  0.29048067735072514,
#  0.21232136122636158,
#  0.35628885600090476,
#  0.45471261345371305,
#  0.27046571627578786,
#  0.23878718744551622,
#  0.33153070589097033,
#  0.25026105721666125,
#  0.342801568222564,
#  nan,
#  0.21313807874686314,
#  0.26304655025886015,
#  0.3187113089110959,
#  0.17599090232610504,
#  0.436820530138279,
#  0.10532563175957947,
#  0.3674843995705147,
#  0.25936144281234064,
#  0.23702082970775049,
#  0.3422792689020235,
#  0.24366724898320075,
# ...

# %%
std_12m.rank()
# Out:
# A005930    102.0
# A000660    258.0
# A051910    187.0
# A005380    436.0
# A068270    695.0
#            ...
# A139200      NaN
# A149130      NaN
# A192520      NaN
# A192530    116.0
# A307950      NaN
# Length: 1130, dtype: float64

# %%
for i in range(len(std_12m)):
    if std_12m[i] == 0:
        std_12m[i] = NA
std_12m
# Out:
# [0.20100045473985656,
#  0.27508839811917585,
#  0.2453041791999309,
#  0.3635125782165449,
#  0.6436979475917485,
#  0.3322515755948343,
#  0.2868191637789072,
#  0.4607883955968082,
#  0.21132252632506496,
#  0.2050870468326107,
#  0.31538692918887934,
#  0.19394000609238896,
#  0.29625575019512845,
#  0.320116946888429,
#  0.13693102002716562,
#  0.39050910362024,
#  0.155037512956773,
#  0.25940954730014676,
#  0.17145856733355705,
#  0.1394185051017236,
#  0.19330469111071336,
#  0.3060926628375489,
#  0.29048067735072514,
#  0.21232136122636158,
#  0.35628885600090476,
#  0.45471261345371305,
#  0.27046571627578786,
#  0.23878718744551622,
#  0.33153070589097033,
#  0.25026105721666125,
#  0.342801568222564,
#  nan,
#  0.21313807874686314,
#  0.26304655025886015,
#  0.3187113089110959,
#  0.17599090232610504,
#  0.436820530138279,
#  0.10532563175957947,
#  0.3674843995705147,
#  0.25936144281234064,
#  0.23702082970775049,
#  0.3422792689020235,
#  0.24366724898320075,
# ...

# %%
std_12m_ = np.sorted(std_12m, reverse=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-f2213049c190> in <module>
# ----> 1 std_12m_ = np.sorted(std_12m, reverse=True)
#
# AttributeError: module 'numpy' has no attribute 'sorted'

# %%
std_12m_ = sorted(a)
std_12m_.loc['A']
# Out:
# [0.10883049727614741,
#  0.13693102002716562,
#  0.1394185051017236,
#  0.14106351749954868,
#  0.155037512956773,
#  0.17145856733355705,
#  0.17599090232610504,
#  0.18013076696775834,
#  0.18189156880890295,
#  0.19330469111071336,
#  0.19394000609238896,
#  0.19641658717674484,
#  0.19881987034283072,
#  0.20043652486468533,
#  0.20100045473985656,
#  0.2050870468326107,
#  0.20666299243879974,
#  0.20978148921770715,
#  0.21017742826947758,
#  0.21132252632506496,
#  0.21232136122636158,
#  0.2129314948137421,
#  0.21313807874686314,
#  0.2231187966251295,
#  0.2361657208038952,
#  0.2385832526230057,
#  0.23878718744551622,
#  0.2453041791999309,
#  0.25026105721666125,
#  0.25143943649059436,
#  0.25166237107487877,
#  0.25281741222058063,
#  0.2547219802583384,
#  0.25694060987280853,
#  0.25940954730014676,
#  0.26304655025886015,
#  0.27046571627578786,
#  0.2716974052821225,
#  0.27508839811917585,
#  0.28474704102482806,
#  0.2868191637789072,
#  0.29048067735072514,
# ...

# %%
a.sort_values()#ascending=False)
# Out:
# A083380    0.019164
# A034590    0.025491
# A083370    0.030560
# A002250    0.061546
# A000480    0.062160
#              ...
# A138440         NaN
# A139200         NaN
# A149130         NaN
# A192520         NaN
# A307950         NaN
# Length: 1130, dtype: float64

# %%
portfolio = raw_data[ticker["종목코드"].iloc[0]] + raw_data[ticker["종목코드"].iloc[30]] + raw_data[ticker["종목코드"].iloc[115]]
spfd1 = raw_data[ticker["종목코드"].iloc[0]]
spfd2 = raw_data[ticker["종목코드"].iloc[30]]
spfd3 = raw_data[ticker["종목코드"].iloc[115]]
plt.figure()
plt.plot(portfolio, 'black')
plt.plot(spfd1, 'r')
plt.plot(spfd2, 'g')
plt.plot(spfd3, 'b')
plt.show()

# %%
spfd1 = raw_data["A034590"]
spfd2 = raw_data["A083380"]
spfd3 = raw_data["A083370"]
portfolio = spfd1 + spfd2 + spfd3
plt.figure()
plt.plot(portfolio, 'black')
plt.plot(spfd1, 'r')
plt.plot(spfd2, 'g')
plt.plot(spfd3, 'b')
plt.show()
