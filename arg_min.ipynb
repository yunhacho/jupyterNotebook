# %%
import numpy as np
import matplotlib.pyplot as plt

# target : f(x) = x1^2 + x2^2
def f1(x1, x2):
    return x1**2 + x2**2 + 3*x1*x2

x1 = np.linspace(-10, 10, 100)
x2 = np.linspace(-3, 3, 100)
X1, X2 = np.meshgrid(x1, x2)
Y = f1(X1, X2)

# 제한 조건 g(x) = x1 + x2 -1 = 0
x2_g = 1 - x1
plt.contour(X1, X2, Y, levels=[0.5, 2, 8,16, 32],)
plt.plot(x1, x2_g, 'b+')
#pcmesh = plt.pcolormesh(X1, X2, Y)
plt.colorbar()

plt.plot([0], [0], 'rP') #원점
plt.plot([0.5], [0.5], 'ro', ms=10) # 해(빨간 원)

plt.xlim(-5, 5)
plt.ylim(-3, 3)#축의 범위를 제한하는 함수 xlim, ylim

plt.xticks(np.linspace(-4, 4, 9)) #축 편집
plt.xlabel("$x_1$")
plt.ylabel("$x_2$") #축라벨링
plt.title("restricted optimization") #타이틀
plt.show()

# %matplotlib inline

# %%
x = np.linspace(-2*np.pi,2*np.pi);
y = np.linspace(0,4*np.pi);
[X,Y] = np.meshgrid(x,y);
Z = np.sin(X)+np.cos(Y);
plt.contour(X,Y,Z)
plt.colorbar()

# %%
np.pi
# Out:
# 3.141592653589793

# %%
a = [[1,2,3],[4,5,6]]
plt.plot(a)

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import scipy as sp
from scipy import optimize
def f1array(x):
    return x[0] ** 2 + x[1] ** 2


def eq_constraint(x):
    return x[0] + x[1] - 1


sp.optimize.fmin_slsqp(f1array, np.array([3,3]), eqcons=[eq_constraint])
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5000000000000004
#             Iterations: 2
#             Function evaluations: 8
#             Gradient evaluations: 2
# array([0.5, 0.5])

# %%
w = [1,2,3]
def eq_constraint0(w):
    for i in w:
        print(i)
eq_constraint(w)
# Out:
# 6

# %%
def eq_constraint(w):
    summation = 0
    for i in w:
        summation += i
    return summation -1
eq_constraint([1,2,3])
# Out:
# 5

# %%
def eq_constraint(w):
    summation = 0
    for i in w:
        summation += i
    return summation -1


def flarray(w):
    summation = 0
    N = len(w)
    for wi in w:
        summation += (wi - risk/(N* np.dot(var_cov_mat, w)))**2
    return summation
sp.optimize.fmin_slsqp(f1array, np.array([0.5, 0.25, 0.25]), eqcons=[eq_constraint])
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0829833337926442e-16
#             Iterations: 4
#             Function evaluations: 20
#             Gradient evaluations: 4
# array([-7.41177546e-09, -7.30506111e-09,  1.00000001e+00])

# %%
sp.optimize.fmin_slsqp(f1array, np.array([1/3, 1/3, 1/3]), eqcons=[eq_constraint])
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5
#             Iterations: 3
#             Function evaluations: 16
#             Gradient evaluations: 3
# array([0.5       , 0.5       , 0.33333333])
